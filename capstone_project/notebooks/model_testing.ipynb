# %% [markdown]
# # Training Evaluation

# %%
# importing necessary packages and libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras import models
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import pickle
# %matplotlib inline

# %%
# importing swish
from functions.swish import *
add_swish()

# %%
model_13 = models.load_model('../notebooks/model_construction/saved_models/model_13.h5')

# %%
from functions.plot_evaluation import plot_evaluation

# %%
plot_evaluation('model_13')

# %% [markdown]
# # Testing

# %%
# loading the testing data
X_test_non_norm = np.load('../data/0002_array_data/test_data/X_test_data.npy')
X_test = X_test_non_norm*(1./255)
y_test = np.load('../data/0002_array_data/test_data/y_test_data.npy')

# %%
(test_loss, test_accuracy) = model_13.evaluate(X_test,y_test,verbose=1)
# Out:
# 39/39 [==============================] - 78s 2s/step - loss: 0.6675 - acc: 0.8118

# %%
print(f'Test Accuracy: {round((test_accuracy*100),2)}%')
print(f'Test Loss: {round(test_loss,4)}')
# Out:
# Test Accuracy: 81.18%
# Test Loss: 0.6675

# %%
y_pred = np.argmax(model_13.predict(X_test,verbose=1),axis=-1)
# Out:
# 39/39 [==============================] - 92s 2s/step

# %%
# importing the confusion matrix function
from functions.make_cm import make_cm

# %%
make_cm(y_pred,y_test,model_name='model_13')

# %%
from functions.test_inspect import test_inspect

# %%
test_inspect(y_pred,y_test,model_name='model_13')

# %%
from functions.classify_test_image import classify_test_image

# %%
classify_test_image(247,model_name='model_13')
# Out:
# Actual: bolete
# Predicted: bolete
# Result: Correct!
