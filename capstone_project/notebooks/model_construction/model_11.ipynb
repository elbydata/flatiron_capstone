# %% [markdown]
# # Model 11: Longer Training Run

# %% [markdown]
# This notebook contains the construction and training of the model iterations and various experiments. The notebook is split up into four sections: training mode selection (where the model will run), set-up, model constrution, and training.
#
# Evaluation will take place in the *model_optimization_and_evaluation.ipynb* notebook found in the *notebooks* folder.

# %%
# importing necessary packages and libraries
import numpy as np
import pandas as pd
from keras import layers
from keras import models
from keras import optimizers
from keras import applications 
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import pickle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Step 1: Training Mode Selection

# %% [markdown]
# In the cell below, specify the training mode for the model. This will determine the location from which the source data is drawn, and to which the trained models (and training histories) are saved.

# %% [markdown]
# - **training_mode = 'floydhub'** (runs on Floydhub)
# - **training_mode = 'local'** (runs on local disk and processor)

# %%
# select training mode
training_mode = 'floydhub'

# %% [markdown]
# ## Step 2: Set-up

# %%
# directory base paths
data_path_local = '../../data/0002_array_data/train_data/'
model_path_local = '../../notebooks/model_construction/saved_models/'
data_path_floydhub = '/floyd/input/capstone_mushrooms/'
model_path_floydhub = '/floyd/home/'

# setting directory paths based on training mode selection
if training_mode == 'floydhub':
    data_path = data_path_floydhub
    model_path = model_path_floydhub
elif training_mode == 'local':
    data_path = data_path_local
    model_path = model_path_local
else:
    raise Exception('Please choose valid training mode: "floydhub" or "local".')

# %%
# loading the training and validation data subsets
X_train = np.load(f'{data_path}X_train_data.npy')
y_train = np.load(f'{data_path}y_train_data.npy')
X_val = np.load(f'{data_path}X_val_data.npy')
y_val = np.load(f'{data_path}y_val_data.npy')

# %%
# setting training parameters
batch_size = 8
n_classes = 20
n_epochs = 100
img_shape = X_train.shape[1:]
model_names = []
model_list = []
model_hists = []

# %% [markdown]
# ## Step 3: Model Construction

# %% [markdown]
# ### Trial 1

# %%
# defining the model architecture
m11_t1 = models.Sequential()

# convolution/max pool stacks
m11_t1.add(layers.Conv2D(32,(3,3), input_shape=img_shape, padding='same'))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.MaxPooling2D((2,2)))

m11_t1.add(layers.Conv2D(64,(3,3), padding='same'))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.MaxPooling2D((2,2)))

m11_t1.add(layers.Conv2D(128,(3,3), padding='same'))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.MaxPooling2D((2,2)))

m11_t1.add(layers.Conv2D(256,(3,3), padding='same'))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.MaxPooling2D((2,2)))

m11_t1.add(layers.Conv2D(512,(3,3), padding='same'))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.MaxPooling2D((2,2)))

# fully connected layers
m11_t1.add(layers.Flatten())
m11_t1.add(layers.Dense(1024))
m11_t1.add(layers.LeakyReLU(alpha=0.1))
m11_t1.add(layers.Dense(n_classes, activation='softmax'))

# reviewing the model architecture and adding model and name to list
m11_t1.summary()
model_names.append('m11_t1')
model_list.append(m11_t1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 32)      896
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200, 200, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 100, 64)      18496
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 50, 50, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 256)       295168
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 25, 25, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              18875392
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                20500
# =================================================================
# Total params: 20,464,468
# Trainable params: 20,464,468
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 4: Training

# %%
# setting up standardization and augmentation parameters
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=40,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   fill_mode='nearest',
                                   horizontal_flip=True,
                                   vertical_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# %%time
# data standardization and augmentation
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)
# Out:
# CPU times: user 318 ms, sys: 966 ms, total: 1.28 s
# Wall time: 1.28 s

# %%
# setting up optimizer
opt = optimizers.Adamax(learning_rate=9e-4)

# compiling loss functions
m11_t1.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['acc'])

# %%
# %%time
# setting up model saving checkpoints
m11_t1_cp = ModelCheckpoint(filepath=f'{model_path}m11_t1.h5',
                              monitor='val_acc',
                              verbose=1,
                              save_best_only=True)

# fitting model
m11_t1_history = m11_t1.fit(train_generator,
                                steps_per_epoch=len(X_train)//batch_size,
                                epochs=n_epochs,
                                callbacks=[m11_t1_cp],
                                validation_data=val_generator,
                                validation_steps=len(X_val)//batch_size)

# adding training history to list
model_hists.append(m11_t1_history)
# Out:
# Epoch 1/100
# 1013/1013 [==============================] - 114s 112ms/step - loss: 2.7234 - acc: 0.1404 - val_loss: 1.4549 - val_acc: 0.2252
#
# Epoch 00001: val_acc improved from -inf to 0.22525, saving model to /floyd/home/m11_t1.h5
# Epoch 2/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 2.3280 - acc: 0.2515 - val_loss: 1.7477 - val_acc: 0.3304
#
# Epoch 00002: val_acc improved from 0.22525 to 0.33042, saving model to /floyd/home/m11_t1.h5
# Epoch 3/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 2.1429 - acc: 0.3041 - val_loss: 1.0219 - val_acc: 0.3865
#
# Epoch 00003: val_acc improved from 0.33042 to 0.38653, saving model to /floyd/home/m11_t1.h5
# Epoch 4/100
# 1013/1013 [==============================] - 76s 76ms/step - loss: 2.0221 - acc: 0.3506 - val_loss: 1.1718 - val_acc: 0.4352
#
# Epoch 00004: val_acc improved from 0.38653 to 0.43516, saving model to /floyd/home/m11_t1.h5
# Epoch 5/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.9331 - acc: 0.3706 - val_loss: 1.8853 - val_acc: 0.4738
#
# Epoch 00005: val_acc improved from 0.43516 to 0.47382, saving model to /floyd/home/m11_t1.h5
# Epoch 6/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.8255 - acc: 0.4166 - val_loss: 1.4621 - val_acc: 0.4975
#
# Epoch 00006: val_acc improved from 0.47382 to 0.49751, saving model to /floyd/home/m11_t1.h5
# Epoch 7/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.7710 - acc: 0.4335 - val_loss: 2.1908 - val_acc: 0.4888
#
# Epoch 00007: val_acc did not improve from 0.49751
# Epoch 8/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.6980 - acc: 0.4551 - val_loss: 2.4069 - val_acc: 0.4988
#
# Epoch 00008: val_acc improved from 0.49751 to 0.49875, saving model to /floyd/home/m11_t1.h5
# Epoch 9/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.6436 - acc: 0.4725 - val_loss: 1.4732 - val_acc: 0.5536
#
# Epoch 00009: val_acc improved from 0.49875 to 0.55362, saving model to /floyd/home/m11_t1.h5
# Epoch 10/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.5895 - acc: 0.4951 - val_loss: 0.7742 - val_acc: 0.5125
#
# Epoch 00010: val_acc did not improve from 0.55362
# Epoch 11/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.5459 - acc: 0.5065 - val_loss: 1.2254 - val_acc: 0.5673
#
# Epoch 00011: val_acc improved from 0.55362 to 0.56733, saving model to /floyd/home/m11_t1.h5
# Epoch 12/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.4968 - acc: 0.5201 - val_loss: 1.8475 - val_acc: 0.5948
#
# Epoch 00012: val_acc improved from 0.56733 to 0.59476, saving model to /floyd/home/m11_t1.h5
# Epoch 13/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.4505 - acc: 0.5320 - val_loss: 1.6268 - val_acc: 0.5848
#
# Epoch 00013: val_acc did not improve from 0.59476
# Epoch 14/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.4023 - acc: 0.5468 - val_loss: 1.3831 - val_acc: 0.5973
#
# Epoch 00014: val_acc improved from 0.59476 to 0.59726, saving model to /floyd/home/m11_t1.h5
# Epoch 15/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.3775 - acc: 0.5600 - val_loss: 1.6344 - val_acc: 0.5536
#
# Epoch 00015: val_acc did not improve from 0.59726
# Epoch 16/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.3209 - acc: 0.5809 - val_loss: 0.2746 - val_acc: 0.5935
#
# Epoch 00016: val_acc did not improve from 0.59726
# Epoch 17/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.2800 - acc: 0.5926 - val_loss: 1.3830 - val_acc: 0.5898
#
# Epoch 00017: val_acc did not improve from 0.59726
# Epoch 18/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.2604 - acc: 0.5962 - val_loss: 1.1333 - val_acc: 0.6010
#
# Epoch 00018: val_acc improved from 0.59726 to 0.60100, saving model to /floyd/home/m11_t1.h5
# Epoch 19/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.2221 - acc: 0.6068 - val_loss: 0.4984 - val_acc: 0.6284
#
# Epoch 00019: val_acc improved from 0.60100 to 0.62843, saving model to /floyd/home/m11_t1.h5
# Epoch 20/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 1.1866 - acc: 0.6160 - val_loss: 1.0210 - val_acc: 0.6197
#
# Epoch 00020: val_acc did not improve from 0.62843
# Epoch 21/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.1487 - acc: 0.6311 - val_loss: 2.0116 - val_acc: 0.6945
#
# Epoch 00021: val_acc improved from 0.62843 to 0.69451, saving model to /floyd/home/m11_t1.h5
# Epoch 22/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.1225 - acc: 0.6364 - val_loss: 1.3065 - val_acc: 0.6060
#
# Epoch 00022: val_acc did not improve from 0.69451
# Epoch 23/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.0936 - acc: 0.6469 - val_loss: 1.1365 - val_acc: 0.6895
#
# Epoch 00023: val_acc did not improve from 0.69451
# Epoch 24/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.0567 - acc: 0.6578 - val_loss: 1.2972 - val_acc: 0.6334
#
# Epoch 00024: val_acc did not improve from 0.69451
# Epoch 25/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.0378 - acc: 0.6653 - val_loss: 0.9460 - val_acc: 0.6484
#
# Epoch 00025: val_acc did not improve from 0.69451
# Epoch 26/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.9977 - acc: 0.6769 - val_loss: 0.8636 - val_acc: 0.6908
#
# Epoch 00026: val_acc did not improve from 0.69451
# Epoch 27/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 1.0062 - acc: 0.6763 - val_loss: 0.5472 - val_acc: 0.6908
#
# Epoch 00027: val_acc did not improve from 0.69451
# Epoch 28/100
# 1013/1013 [==============================] - 78s 77ms/step - loss: 0.9640 - acc: 0.6828 - val_loss: 1.7266 - val_acc: 0.6970
#
# Epoch 00028: val_acc improved from 0.69451 to 0.69701, saving model to /floyd/home/m11_t1.h5
# Epoch 29/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.9577 - acc: 0.6921 - val_loss: 1.7931 - val_acc: 0.6783
#
# Epoch 00029: val_acc did not improve from 0.69701
# Epoch 30/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.9322 - acc: 0.6990 - val_loss: 1.7639 - val_acc: 0.7095
#
# Epoch 00030: val_acc improved from 0.69701 to 0.70948, saving model to /floyd/home/m11_t1.h5
# Epoch 31/100
# 1013/1013 [==============================] - 78s 77ms/step - loss: 0.8948 - acc: 0.7130 - val_loss: 0.4990 - val_acc: 0.6783
#
# Epoch 00031: val_acc did not improve from 0.70948
# Epoch 32/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.8720 - acc: 0.7190 - val_loss: 0.4252 - val_acc: 0.6771
#
# Epoch 00032: val_acc did not improve from 0.70948
# Epoch 33/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.8571 - acc: 0.7221 - val_loss: 0.1727 - val_acc: 0.6559
#
# Epoch 00033: val_acc did not improve from 0.70948
# Epoch 34/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.8592 - acc: 0.7237 - val_loss: 1.2061 - val_acc: 0.6958
#
# Epoch 00034: val_acc did not improve from 0.70948
# Epoch 35/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.8153 - acc: 0.7347 - val_loss: 0.7030 - val_acc: 0.7307
#
# Epoch 00035: val_acc improved from 0.70948 to 0.73067, saving model to /floyd/home/m11_t1.h5
# Epoch 36/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.8102 - acc: 0.7391 - val_loss: 0.8544 - val_acc: 0.7307
#
# Epoch 00036: val_acc did not improve from 0.73067
# Epoch 37/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.7824 - acc: 0.7462 - val_loss: 2.2721 - val_acc: 0.6883
#
# Epoch 00037: val_acc did not improve from 0.73067
# Epoch 38/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.7654 - acc: 0.7533 - val_loss: 2.6806 - val_acc: 0.6446
#
# Epoch 00038: val_acc did not improve from 0.73067
# Epoch 39/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.7505 - acc: 0.7570 - val_loss: 0.7544 - val_acc: 0.6970
#
# Epoch 00039: val_acc did not improve from 0.73067
# Epoch 40/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.7405 - acc: 0.7532 - val_loss: 1.2138 - val_acc: 0.7481
#
# Epoch 00040: val_acc improved from 0.73067 to 0.74813, saving model to /floyd/home/m11_t1.h5
# Epoch 41/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.7329 - acc: 0.7628 - val_loss: 1.0911 - val_acc: 0.6883
#
# Epoch 00041: val_acc did not improve from 0.74813
# Epoch 42/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.7087 - acc: 0.7736 - val_loss: 1.1774 - val_acc: 0.7095
#
# Epoch 00042: val_acc did not improve from 0.74813
# Epoch 43/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.7020 - acc: 0.7697 - val_loss: 1.2666 - val_acc: 0.7070
#
# Epoch 00043: val_acc did not improve from 0.74813
# Epoch 44/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6785 - acc: 0.7782 - val_loss: 0.9769 - val_acc: 0.6870
#
# Epoch 00044: val_acc did not improve from 0.74813
# Epoch 45/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6644 - acc: 0.7810 - val_loss: 1.4007 - val_acc: 0.7045
#
# Epoch 00045: val_acc did not improve from 0.74813
# Epoch 46/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.6600 - acc: 0.7880 - val_loss: 1.5782 - val_acc: 0.7207
#
# Epoch 00046: val_acc did not improve from 0.74813
# Epoch 47/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6401 - acc: 0.7907 - val_loss: 1.0961 - val_acc: 0.6983
#
# Epoch 00047: val_acc did not improve from 0.74813
# Epoch 48/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6348 - acc: 0.7920 - val_loss: 1.1850 - val_acc: 0.6983
#
# Epoch 00048: val_acc did not improve from 0.74813
# Epoch 49/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6191 - acc: 0.7977 - val_loss: 1.0614 - val_acc: 0.7195
#
# Epoch 00049: val_acc did not improve from 0.74813
# Epoch 50/100
# 1013/1013 [==============================] - 75s 74ms/step - loss: 0.6154 - acc: 0.7969 - val_loss: 0.0570 - val_acc: 0.7481
#
# Epoch 00050: val_acc did not improve from 0.74813
# Epoch 51/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.6105 - acc: 0.8006 - val_loss: 1.6368 - val_acc: 0.7469
#
# Epoch 00051: val_acc did not improve from 0.74813
# Epoch 52/100
# 1013/1013 [==============================] - 75s 74ms/step - loss: 0.5846 - acc: 0.8126 - val_loss: 0.7227 - val_acc: 0.7095
#
# Epoch 00052: val_acc did not improve from 0.74813
# Epoch 53/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5757 - acc: 0.8142 - val_loss: 0.5813 - val_acc: 0.7107
#
# Epoch 00053: val_acc did not improve from 0.74813
# Epoch 54/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5564 - acc: 0.8180 - val_loss: 1.5425 - val_acc: 0.7456
#
# Epoch 00054: val_acc did not improve from 0.74813
# Epoch 55/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5361 - acc: 0.8254 - val_loss: 0.6883 - val_acc: 0.7344
#
# Epoch 00055: val_acc did not improve from 0.74813
# Epoch 56/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5412 - acc: 0.8263 - val_loss: 0.5919 - val_acc: 0.7481
#
# Epoch 00056: val_acc did not improve from 0.74813
# Epoch 57/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.5327 - acc: 0.8301 - val_loss: 0.9485 - val_acc: 0.7307
#
# Epoch 00057: val_acc did not improve from 0.74813
# Epoch 58/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5241 - acc: 0.8278 - val_loss: 0.7702 - val_acc: 0.7369
#
# Epoch 00058: val_acc did not improve from 0.74813
# Epoch 59/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5124 - acc: 0.8269 - val_loss: 0.6584 - val_acc: 0.7519
#
# Epoch 00059: val_acc improved from 0.74813 to 0.75187, saving model to /floyd/home/m11_t1.h5
# Epoch 60/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.4832 - acc: 0.8378 - val_loss: 0.6624 - val_acc: 0.7494
#
# Epoch 00060: val_acc did not improve from 0.75187
# Epoch 61/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.5104 - acc: 0.8326 - val_loss: 0.3969 - val_acc: 0.7569
#
# Epoch 00061: val_acc improved from 0.75187 to 0.75686, saving model to /floyd/home/m11_t1.h5
# Epoch 62/100
# 1013/1013 [==============================] - 76s 76ms/step - loss: 0.4805 - acc: 0.8419 - val_loss: 2.9101 - val_acc: 0.7581
#
# Epoch 00062: val_acc improved from 0.75686 to 0.75810, saving model to /floyd/home/m11_t1.h5
# Epoch 63/100
# 1013/1013 [==============================] - 77s 76ms/step - loss: 0.4878 - acc: 0.8417 - val_loss: 0.1479 - val_acc: 0.7282
#
# Epoch 00063: val_acc did not improve from 0.75810
# Epoch 64/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4849 - acc: 0.8410 - val_loss: 0.3276 - val_acc: 0.7045
#
# Epoch 00064: val_acc did not improve from 0.75810
# Epoch 65/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4535 - acc: 0.8515 - val_loss: 1.8786 - val_acc: 0.7269
#
# Epoch 00065: val_acc did not improve from 0.75810
# Epoch 66/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4533 - acc: 0.8535 - val_loss: 0.0880 - val_acc: 0.7544
#
# Epoch 00066: val_acc did not improve from 0.75810
# Epoch 67/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4455 - acc: 0.8544 - val_loss: 0.0887 - val_acc: 0.7544
#
# Epoch 00067: val_acc did not improve from 0.75810
# Epoch 68/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4478 - acc: 0.8546 - val_loss: 1.4985 - val_acc: 0.7170
#
# Epoch 00068: val_acc did not improve from 0.75810
# Epoch 69/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4351 - acc: 0.8604 - val_loss: 2.0385 - val_acc: 0.7631
#
# Epoch 00069: val_acc improved from 0.75810 to 0.76309, saving model to /floyd/home/m11_t1.h5
# Epoch 70/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4236 - acc: 0.8610 - val_loss: 0.8872 - val_acc: 0.7631
#
# Epoch 00070: val_acc did not improve from 0.76309
# Epoch 71/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4442 - acc: 0.8556 - val_loss: 1.4316 - val_acc: 0.7519
#
# Epoch 00071: val_acc did not improve from 0.76309
# Epoch 72/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4139 - acc: 0.8672 - val_loss: 1.6097 - val_acc: 0.7569
#
# Epoch 00072: val_acc did not improve from 0.76309
# Epoch 73/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3792 - acc: 0.8740 - val_loss: 0.7573 - val_acc: 0.7606
#
# Epoch 00073: val_acc did not improve from 0.76309
# Epoch 74/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.4005 - acc: 0.8691 - val_loss: 1.1544 - val_acc: 0.7506
#
# Epoch 00074: val_acc did not improve from 0.76309
# Epoch 75/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3941 - acc: 0.8760 - val_loss: 0.0874 - val_acc: 0.7357
#
# Epoch 00075: val_acc did not improve from 0.76309
# Epoch 76/100
# 1013/1013 [==============================] - 75s 75ms/step - loss: 0.4003 - acc: 0.8686 - val_loss: 0.7873 - val_acc: 0.7107
#
# Epoch 00076: val_acc did not improve from 0.76309
# Epoch 77/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3962 - acc: 0.8711 - val_loss: 1.9829 - val_acc: 0.7357
#
# Epoch 00077: val_acc did not improve from 0.76309
# Epoch 78/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3848 - acc: 0.8748 - val_loss: 1.7721 - val_acc: 0.7419
#
# Epoch 00078: val_acc did not improve from 0.76309
# Epoch 79/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3854 - acc: 0.8744 - val_loss: 2.1245 - val_acc: 0.7219
#
# Epoch 00079: val_acc did not improve from 0.76309
# Epoch 80/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3746 - acc: 0.8781 - val_loss: 0.7431 - val_acc: 0.7257
#
# Epoch 00080: val_acc did not improve from 0.76309
# Epoch 81/100
# 1013/1013 [==============================] - 75s 74ms/step - loss: 0.3480 - acc: 0.8894 - val_loss: 0.7265 - val_acc: 0.7307
#
# Epoch 00081: val_acc did not improve from 0.76309
# Epoch 82/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3543 - acc: 0.8816 - val_loss: 0.1009 - val_acc: 0.7531
#
# Epoch 00082: val_acc did not improve from 0.76309
# Epoch 83/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3629 - acc: 0.8841 - val_loss: 0.4866 - val_acc: 0.7232
#
# Epoch 00083: val_acc did not improve from 0.76309
# Epoch 84/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3663 - acc: 0.8832 - val_loss: 1.5925 - val_acc: 0.7431
#
# Epoch 00084: val_acc did not improve from 0.76309
# Epoch 85/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3417 - acc: 0.8869 - val_loss: 1.0912 - val_acc: 0.7531
#
# Epoch 00085: val_acc did not improve from 0.76309
# Epoch 86/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3437 - acc: 0.8894 - val_loss: 0.7040 - val_acc: 0.7643
#
# Epoch 00086: val_acc improved from 0.76309 to 0.76434, saving model to /floyd/home/m11_t1.h5
# Epoch 87/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3395 - acc: 0.8923 - val_loss: 1.6369 - val_acc: 0.7506
#
# Epoch 00087: val_acc did not improve from 0.76434
# Epoch 88/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3440 - acc: 0.8860 - val_loss: 0.9887 - val_acc: 0.7431
#
# Epoch 00088: val_acc did not improve from 0.76434
# Epoch 89/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3281 - acc: 0.8946 - val_loss: 1.9524 - val_acc: 0.7269
#
# Epoch 00089: val_acc did not improve from 0.76434
# Epoch 90/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3239 - acc: 0.8912 - val_loss: 2.4114 - val_acc: 0.7506
#
# Epoch 00090: val_acc did not improve from 0.76434
# Epoch 91/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3443 - acc: 0.8889 - val_loss: 1.9373 - val_acc: 0.7082
#
# Epoch 00091: val_acc did not improve from 0.76434
# Epoch 92/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3160 - acc: 0.8940 - val_loss: 3.6542 - val_acc: 0.7519
#
# Epoch 00092: val_acc did not improve from 0.76434
# Epoch 93/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3010 - acc: 0.9049 - val_loss: 1.4024 - val_acc: 0.7656
#
# Epoch 00093: val_acc improved from 0.76434 to 0.76559, saving model to /floyd/home/m11_t1.h5
# Epoch 94/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3225 - acc: 0.8969 - val_loss: 0.1864 - val_acc: 0.7581
#
# Epoch 00094: val_acc did not improve from 0.76559
# Epoch 95/100
# 1013/1013 [==============================] - 75s 74ms/step - loss: 0.3172 - acc: 0.8988 - val_loss: 0.6126 - val_acc: 0.7020
#
# Epoch 00095: val_acc did not improve from 0.76559
# Epoch 96/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3164 - acc: 0.8969 - val_loss: 0.5329 - val_acc: 0.7456
#
# Epoch 00096: val_acc did not improve from 0.76559
# Epoch 97/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3051 - acc: 0.9021 - val_loss: 1.0444 - val_acc: 0.7594
#
# Epoch 00097: val_acc did not improve from 0.76559
# Epoch 98/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3049 - acc: 0.9057 - val_loss: 1.7439 - val_acc: 0.7531
#
# Epoch 00098: val_acc did not improve from 0.76559
# Epoch 99/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.3001 - acc: 0.9052 - val_loss: 4.1184 - val_acc: 0.7444
#
# Epoch 00099: val_acc did not improve from 0.76559
# Epoch 100/100
# 1013/1013 [==============================] - 76s 75ms/step - loss: 0.2942 - acc: 0.9069 - val_loss: 2.0327 - val_acc: 0.7531
#
# Epoch 00100: val_acc did not improve from 0.76559
# CPU times: user 3h 3min 10s, sys: 22min 40s, total: 3h 25min 50s
# Wall time: 2h 8min 28s

# %%
# creating dictionary for model names, models, and histories from respective lists
models_dict = {i:[j,k] for i,j,k in zip(model_names,model_list,model_hists)}

# %%
# evaluating models on validation set
for key, value in models_dict.items():
    model = models.load_model(f'{model_path}{key}.h5')
    (val_loss, val_accuracy) = model.evaluate(val_generator,verbose=1)
    print(f'{key} Val Accuracy: {round((val_accuracy*100),2)}%')
    print(f'{key} Val Loss: {round(val_loss,4)}')
    print('---')
# Out:
# 102/102 [==============================] - 2s 19ms/step
# m11_t1 Val Accuracy: 76.17%
# m11_t1 Val Loss: 0.1317
# ---

# %%
# saving training histories
for key, value in models_dict.items():
    with open(f'{model_path}{key}_history', 'wb') as file_pi:
        pickle.dump(value[1].history, file_pi)
    print(f'{key}_history saved in {model_path}')
# Out:
# m11_t1_history saved in /floyd/home/
