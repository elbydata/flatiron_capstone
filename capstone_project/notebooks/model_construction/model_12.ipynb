# %% [markdown]
# # Model 12: Additional Capacity

# %% [markdown]
# This notebook contains the construction and training of the model iterations and various experiments. The notebook is split up into four sections: training mode selection (where the model will run), set-up, model constrution, and training.
#
# Evaluation will take place in the *model_optimization_and_evaluation.ipynb* notebook found in the *notebooks* folder.

# %%
# importing necessary packages and libraries
import numpy as np
import pandas as pd
from keras import layers
from keras import models
from keras import optimizers
from keras import applications 
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import pickle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Step 1: Training Mode Selection

# %% [markdown]
# In the cell below, specify the training mode for the model. This will determine the location from which the source data is drawn, and to which the trained models (and training histories) are saved.

# %% [markdown]
# - **training_mode = 'floydhub'** (runs on Floydhub)
# - **training_mode = 'local'** (runs on local disk and processor)

# %%
# select training mode
training_mode = 'floydhub'

# %% [markdown]
# ## Step 2: Set-up

# %%
# directory base paths
data_path_local = '../../data/0002_array_data/train_data/'
model_path_local = '../../notebooks/model_construction/saved_models/'
data_path_floydhub = '/floyd/input/capstone_mushrooms/'
model_path_floydhub = '/floyd/home/'

# setting directory paths based on training mode selection
if training_mode == 'floydhub':
    data_path = data_path_floydhub
    model_path = model_path_floydhub
elif training_mode == 'local':
    data_path = data_path_local
    model_path = model_path_local
else:
    raise Exception('Please choose valid training mode: "floydhub" or "local".')

# %%
# loading the training and validation data subsets
X_train = np.load(f'{data_path}X_train_data.npy')
y_train = np.load(f'{data_path}y_train_data.npy')
X_val = np.load(f'{data_path}X_val_data.npy')
y_val = np.load(f'{data_path}y_val_data.npy')

# %%
# setting training parameters
batch_size = 8
n_classes = 20
n_epochs = 100
img_shape = X_train.shape[1:]
model_names = []
model_list = []
model_hists = []

# %% [markdown]
# ## Step 3: Model Construction

# %% [markdown]
# ### Trial 1

# %%
# defining the model architecture
m12_t1 = models.Sequential()

# convolution/max pool stacks
m12_t1.add(layers.Conv2D(64,(3,3), input_shape=img_shape, padding='same'))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.MaxPooling2D((2,2)))

m12_t1.add(layers.Conv2D(128,(3,3), padding='same'))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.MaxPooling2D((2,2)))

m12_t1.add(layers.Conv2D(256,(3,3), padding='same'))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.MaxPooling2D((2,2)))

m12_t1.add(layers.Conv2D(512,(3,3), padding='same'))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.MaxPooling2D((2,2)))

m12_t1.add(layers.Conv2D(512,(3,3), padding='same'))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.MaxPooling2D((2,2)))

# fully connected layers
m12_t1.add(layers.Flatten())
m12_t1.add(layers.Dense(1024))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.Dropout(0.25))
m12_t1.add(layers.Dense(1024))
m12_t1.add(layers.LeakyReLU(alpha=0.1))
m12_t1.add(layers.Dropout(0.25))
m12_t1.add(layers.Dense(n_classes, activation='softmax'))

# reviewing the model architecture and adding model and name to list
m12_t1.summary()
model_names.append('m12_t1')
model_list.append(m12_t1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200, 200, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 50, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 256)       295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 50, 50, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 25, 25, 512)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 512)       2359808
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              18875392
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                20500
# =================================================================
# Total params: 23,856,276
# Trainable params: 23,856,276
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 4: Training

# %%
# setting up standardization and augmentation parameters
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=40,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   fill_mode='nearest',
                                   horizontal_flip=True,
                                   vertical_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# %%time
# data standardization and augmentation
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)
# Out:
# CPU times: user 356 ms, sys: 957 ms, total: 1.31 s
# Wall time: 1.31 s

# %%
# setting up optimizer
opt = optimizers.Adamax(learning_rate=9e-4)

# compiling loss functions
m12_t1.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['acc'])

# %%
# %%time
# setting up model saving checkpoints
m12_t1_cp = ModelCheckpoint(filepath=f'{model_path}m12_t1.h5',
                              monitor='val_acc',
                              verbose=1,
                              save_best_only=True)

# fitting model
m12_t1_history = m12_t1.fit(train_generator,
                                steps_per_epoch=len(X_train)//batch_size,
                                epochs=n_epochs,
                                callbacks=[m12_t1_cp],
                                validation_data=val_generator,
                                validation_steps=len(X_val)//batch_size)

# adding training history to list
model_hists.append(m12_t1_history)
# Out:
# Epoch 1/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 2.7516 - acc: 0.1133 - val_loss: 2.5491 - val_acc: 0.1968
#
# Epoch 00001: val_acc improved from -inf to 0.19678, saving model to /floyd/home/m12_t1.h5
# Epoch 2/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 2.4237 - acc: 0.2085 - val_loss: 2.5703 - val_acc: 0.3017
#
# Epoch 00002: val_acc improved from 0.19678 to 0.30175, saving model to /floyd/home/m12_t1.h5
# Epoch 3/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 2.2348 - acc: 0.2728 - val_loss: 1.9672 - val_acc: 0.3167
#
# Epoch 00003: val_acc improved from 0.30175 to 0.31671, saving model to /floyd/home/m12_t1.h5
# Epoch 4/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 2.1272 - acc: 0.3023 - val_loss: 1.5841 - val_acc: 0.4077
#
# Epoch 00004: val_acc improved from 0.31671 to 0.40773, saving model to /floyd/home/m12_t1.h5
# Epoch 5/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 2.0049 - acc: 0.3501 - val_loss: 3.2409 - val_acc: 0.3953
#
# Epoch 00005: val_acc did not improve from 0.40773
# Epoch 6/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.9238 - acc: 0.3860 - val_loss: 1.6087 - val_acc: 0.4738
#
# Epoch 00006: val_acc improved from 0.40773 to 0.47382, saving model to /floyd/home/m12_t1.h5
# Epoch 7/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.8401 - acc: 0.4112 - val_loss: 1.3377 - val_acc: 0.5000
#
# Epoch 00007: val_acc improved from 0.47382 to 0.50000, saving model to /floyd/home/m12_t1.h5
# Epoch 8/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.7698 - acc: 0.4363 - val_loss: 2.0644 - val_acc: 0.5798
#
# Epoch 00008: val_acc improved from 0.50000 to 0.57980, saving model to /floyd/home/m12_t1.h5
# Epoch 9/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.7223 - acc: 0.4525 - val_loss: 2.6453 - val_acc: 0.4564
#
# Epoch 00009: val_acc did not improve from 0.57980
# Epoch 10/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.6620 - acc: 0.4672 - val_loss: 1.2951 - val_acc: 0.5611
#
# Epoch 00010: val_acc did not improve from 0.57980
# Epoch 11/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.6003 - acc: 0.4911 - val_loss: 1.3679 - val_acc: 0.5873
#
# Epoch 00011: val_acc improved from 0.57980 to 0.58728, saving model to /floyd/home/m12_t1.h5
# Epoch 12/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.5504 - acc: 0.5040 - val_loss: 1.3096 - val_acc: 0.5411
#
# Epoch 00012: val_acc did not improve from 0.58728
# Epoch 13/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.5075 - acc: 0.5162 - val_loss: 1.7495 - val_acc: 0.5748
#
# Epoch 00013: val_acc did not improve from 0.58728
# Epoch 14/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.4477 - acc: 0.5357 - val_loss: 1.9977 - val_acc: 0.5150
#
# Epoch 00014: val_acc did not improve from 0.58728
# Epoch 15/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.4323 - acc: 0.5442 - val_loss: 1.2726 - val_acc: 0.6297
#
# Epoch 00015: val_acc improved from 0.58728 to 0.62968, saving model to /floyd/home/m12_t1.h5
# Epoch 16/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.3695 - acc: 0.5694 - val_loss: 0.6475 - val_acc: 0.5623
#
# Epoch 00016: val_acc did not improve from 0.62968
# Epoch 17/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.3234 - acc: 0.5805 - val_loss: 0.5498 - val_acc: 0.6309
#
# Epoch 00017: val_acc improved from 0.62968 to 0.63092, saving model to /floyd/home/m12_t1.h5
# Epoch 18/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.2980 - acc: 0.5856 - val_loss: 1.4740 - val_acc: 0.6459
#
# Epoch 00018: val_acc improved from 0.63092 to 0.64589, saving model to /floyd/home/m12_t1.h5
# Epoch 19/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.2528 - acc: 0.6020 - val_loss: 0.6739 - val_acc: 0.6621
#
# Epoch 00019: val_acc improved from 0.64589 to 0.66209, saving model to /floyd/home/m12_t1.h5
# Epoch 20/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.2307 - acc: 0.6065 - val_loss: 1.6919 - val_acc: 0.5935
#
# Epoch 00020: val_acc did not improve from 0.66209
# Epoch 21/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.1978 - acc: 0.6223 - val_loss: 1.4275 - val_acc: 0.6110
#
# Epoch 00021: val_acc did not improve from 0.66209
# Epoch 22/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.1529 - acc: 0.6289 - val_loss: 0.2899 - val_acc: 0.6359
#
# Epoch 00022: val_acc did not improve from 0.66209
# Epoch 23/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 1.1160 - acc: 0.6433 - val_loss: 0.3131 - val_acc: 0.6135
#
# Epoch 00023: val_acc did not improve from 0.66209
# Epoch 24/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.1042 - acc: 0.6453 - val_loss: 1.8642 - val_acc: 0.6185
#
# Epoch 00024: val_acc did not improve from 0.66209
# Epoch 25/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.0646 - acc: 0.6577 - val_loss: 1.4418 - val_acc: 0.6845
#
# Epoch 00025: val_acc improved from 0.66209 to 0.68454, saving model to /floyd/home/m12_t1.h5
# Epoch 26/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.0598 - acc: 0.6599 - val_loss: 0.8240 - val_acc: 0.6858
#
# Epoch 00026: val_acc improved from 0.68454 to 0.68579, saving model to /floyd/home/m12_t1.h5
# Epoch 27/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.0241 - acc: 0.6674 - val_loss: 0.7386 - val_acc: 0.7157
#
# Epoch 00027: val_acc improved from 0.68579 to 0.71571, saving model to /floyd/home/m12_t1.h5
# Epoch 28/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 1.0116 - acc: 0.6815 - val_loss: 0.4740 - val_acc: 0.6945
#
# Epoch 00028: val_acc did not improve from 0.71571
# Epoch 29/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.9725 - acc: 0.6896 - val_loss: 1.2602 - val_acc: 0.6883
#
# Epoch 00029: val_acc did not improve from 0.71571
# Epoch 30/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.9587 - acc: 0.6864 - val_loss: 1.2837 - val_acc: 0.7357
#
# Epoch 00030: val_acc improved from 0.71571 to 0.73566, saving model to /floyd/home/m12_t1.h5
# Epoch 31/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.9323 - acc: 0.7040 - val_loss: 0.9135 - val_acc: 0.7107
#
# Epoch 00031: val_acc did not improve from 0.73566
# Epoch 32/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.9352 - acc: 0.7035 - val_loss: 0.9131 - val_acc: 0.6883
#
# Epoch 00032: val_acc did not improve from 0.73566
# Epoch 33/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.8987 - acc: 0.7126 - val_loss: 1.5500 - val_acc: 0.7294
#
# Epoch 00033: val_acc did not improve from 0.73566
# Epoch 34/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.9029 - acc: 0.7110 - val_loss: 1.3636 - val_acc: 0.7344
#
# Epoch 00034: val_acc did not improve from 0.73566
# Epoch 35/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.8647 - acc: 0.7258 - val_loss: 1.3975 - val_acc: 0.7020
#
# Epoch 00035: val_acc did not improve from 0.73566
# Epoch 36/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.8470 - acc: 0.7226 - val_loss: 0.9652 - val_acc: 0.7294
#
# Epoch 00036: val_acc did not improve from 0.73566
# Epoch 37/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.8295 - acc: 0.7349 - val_loss: 1.9973 - val_acc: 0.7232
#
# Epoch 00037: val_acc did not improve from 0.73566
# Epoch 38/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.8131 - acc: 0.7406 - val_loss: 1.0581 - val_acc: 0.7406
#
# Epoch 00038: val_acc improved from 0.73566 to 0.74065, saving model to /floyd/home/m12_t1.h5
# Epoch 39/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.8033 - acc: 0.7462 - val_loss: 1.0240 - val_acc: 0.7332
#
# Epoch 00039: val_acc did not improve from 0.74065
# Epoch 40/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.7834 - acc: 0.7478 - val_loss: 2.8047 - val_acc: 0.7132
#
# Epoch 00040: val_acc did not improve from 0.74065
# Epoch 41/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.7720 - acc: 0.7514 - val_loss: 1.9484 - val_acc: 0.6883
#
# Epoch 00041: val_acc did not improve from 0.74065
# Epoch 42/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.7310 - acc: 0.7614 - val_loss: 1.1814 - val_acc: 0.7207
#
# Epoch 00042: val_acc did not improve from 0.74065
# Epoch 43/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.7483 - acc: 0.7625 - val_loss: 0.2979 - val_acc: 0.7406
#
# Epoch 00043: val_acc did not improve from 0.74065
# Epoch 44/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.7255 - acc: 0.7648 - val_loss: 1.8211 - val_acc: 0.7095
#
# Epoch 00044: val_acc did not improve from 0.74065
# Epoch 45/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.7189 - acc: 0.7721 - val_loss: 0.2569 - val_acc: 0.7681
#
# Epoch 00045: val_acc improved from 0.74065 to 0.76808, saving model to /floyd/home/m12_t1.h5
# Epoch 46/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.6971 - acc: 0.7797 - val_loss: 0.9370 - val_acc: 0.7768
#
# Epoch 00046: val_acc improved from 0.76808 to 0.77681, saving model to /floyd/home/m12_t1.h5
# Epoch 47/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.6924 - acc: 0.7743 - val_loss: 0.2890 - val_acc: 0.6808
#
# Epoch 00047: val_acc did not improve from 0.77681
# Epoch 48/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.7000 - acc: 0.7769 - val_loss: 1.0433 - val_acc: 0.7469
#
# Epoch 00048: val_acc did not improve from 0.77681
# Epoch 49/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6796 - acc: 0.7774 - val_loss: 2.4824 - val_acc: 0.6696
#
# Epoch 00049: val_acc did not improve from 0.77681
# Epoch 50/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6624 - acc: 0.7902 - val_loss: 0.6633 - val_acc: 0.7843
#
# Epoch 00050: val_acc improved from 0.77681 to 0.78429, saving model to /floyd/home/m12_t1.h5
# Epoch 51/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.6445 - acc: 0.7933 - val_loss: 0.8461 - val_acc: 0.7444
#
# Epoch 00051: val_acc did not improve from 0.78429
# Epoch 52/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.6499 - acc: 0.7952 - val_loss: 0.4912 - val_acc: 0.7369
#
# Epoch 00052: val_acc did not improve from 0.78429
# Epoch 53/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6300 - acc: 0.7991 - val_loss: 0.2052 - val_acc: 0.7631
#
# Epoch 00053: val_acc did not improve from 0.78429
# Epoch 54/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6311 - acc: 0.7973 - val_loss: 1.4598 - val_acc: 0.7531
#
# Epoch 00054: val_acc did not improve from 0.78429
# Epoch 55/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6299 - acc: 0.7980 - val_loss: 1.1534 - val_acc: 0.7718
#
# Epoch 00055: val_acc did not improve from 0.78429
# Epoch 56/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6115 - acc: 0.8036 - val_loss: 0.1234 - val_acc: 0.7506
#
# Epoch 00056: val_acc did not improve from 0.78429
# Epoch 57/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.6005 - acc: 0.8021 - val_loss: 0.3563 - val_acc: 0.7731
#
# Epoch 00057: val_acc did not improve from 0.78429
# Epoch 58/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.5914 - acc: 0.8105 - val_loss: 0.6280 - val_acc: 0.7880
#
# Epoch 00058: val_acc improved from 0.78429 to 0.78803, saving model to /floyd/home/m12_t1.h5
# Epoch 59/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5818 - acc: 0.8185 - val_loss: 0.7830 - val_acc: 0.7431
#
# Epoch 00059: val_acc did not improve from 0.78803
# Epoch 60/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5676 - acc: 0.8160 - val_loss: 0.2595 - val_acc: 0.7394
#
# Epoch 00060: val_acc did not improve from 0.78803
# Epoch 61/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5647 - acc: 0.8199 - val_loss: 0.7053 - val_acc: 0.7805
#
# Epoch 00061: val_acc did not improve from 0.78803
# Epoch 62/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5438 - acc: 0.8262 - val_loss: 0.7981 - val_acc: 0.7357
#
# Epoch 00062: val_acc did not improve from 0.78803
# Epoch 63/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5644 - acc: 0.8193 - val_loss: 0.8507 - val_acc: 0.7569
#
# Epoch 00063: val_acc did not improve from 0.78803
# Epoch 64/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.5315 - acc: 0.8271 - val_loss: 0.3391 - val_acc: 0.7656
#
# Epoch 00064: val_acc did not improve from 0.78803
# Epoch 65/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5495 - acc: 0.8274 - val_loss: 0.8591 - val_acc: 0.8030
#
# Epoch 00065: val_acc improved from 0.78803 to 0.80299, saving model to /floyd/home/m12_t1.h5
# Epoch 66/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.5368 - acc: 0.8254 - val_loss: 1.6416 - val_acc: 0.7207
#
# Epoch 00066: val_acc did not improve from 0.80299
# Epoch 67/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5353 - acc: 0.8247 - val_loss: 0.9307 - val_acc: 0.7618
#
# Epoch 00067: val_acc did not improve from 0.80299
# Epoch 68/100
# 1013/1013 [==============================] - 116s 115ms/step - loss: 0.5051 - acc: 0.8396 - val_loss: 0.0982 - val_acc: 0.7880
#
# Epoch 00068: val_acc did not improve from 0.80299
# Epoch 69/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5375 - acc: 0.8291 - val_loss: 1.3875 - val_acc: 0.7818
#
# Epoch 00069: val_acc did not improve from 0.80299
# Epoch 70/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.5006 - acc: 0.8362 - val_loss: 3.5307 - val_acc: 0.7818
#
# Epoch 00070: val_acc did not improve from 0.80299
# Epoch 71/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4907 - acc: 0.8356 - val_loss: 1.1203 - val_acc: 0.7681
#
# Epoch 00071: val_acc did not improve from 0.80299
# Epoch 72/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4954 - acc: 0.8388 - val_loss: 1.3648 - val_acc: 0.8105
#
# Epoch 00072: val_acc improved from 0.80299 to 0.81047, saving model to /floyd/home/m12_t1.h5
# Epoch 73/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4766 - acc: 0.8483 - val_loss: 1.3118 - val_acc: 0.7631
#
# Epoch 00073: val_acc did not improve from 0.81047
# Epoch 74/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4948 - acc: 0.8408 - val_loss: 0.1384 - val_acc: 0.7618
#
# Epoch 00074: val_acc did not improve from 0.81047
# Epoch 75/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4652 - acc: 0.8547 - val_loss: 0.3329 - val_acc: 0.7506
#
# Epoch 00075: val_acc did not improve from 0.81047
# Epoch 76/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4784 - acc: 0.8490 - val_loss: 1.2801 - val_acc: 0.8005
#
# Epoch 00076: val_acc did not improve from 0.81047
# Epoch 77/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4753 - acc: 0.8489 - val_loss: 1.3728 - val_acc: 0.7955
#
# Epoch 00077: val_acc did not improve from 0.81047
# Epoch 78/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4500 - acc: 0.8543 - val_loss: 0.1499 - val_acc: 0.8067
#
# Epoch 00078: val_acc did not improve from 0.81047
# Epoch 79/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4396 - acc: 0.8607 - val_loss: 0.6925 - val_acc: 0.7818
#
# Epoch 00079: val_acc did not improve from 0.81047
# Epoch 80/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4183 - acc: 0.8651 - val_loss: 1.0653 - val_acc: 0.7843
#
# Epoch 00080: val_acc did not improve from 0.81047
# Epoch 81/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4409 - acc: 0.8609 - val_loss: 0.6012 - val_acc: 0.7793
#
# Epoch 00081: val_acc did not improve from 0.81047
# Epoch 82/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4367 - acc: 0.8590 - val_loss: 0.5602 - val_acc: 0.7855
#
# Epoch 00082: val_acc did not improve from 0.81047
# Epoch 83/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4225 - acc: 0.8643 - val_loss: 0.8255 - val_acc: 0.7731
#
# Epoch 00083: val_acc did not improve from 0.81047
# Epoch 84/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4454 - acc: 0.8583 - val_loss: 1.2147 - val_acc: 0.7594
#
# Epoch 00084: val_acc did not improve from 0.81047
# Epoch 85/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4256 - acc: 0.8625 - val_loss: 2.2350 - val_acc: 0.8067
#
# Epoch 00085: val_acc did not improve from 0.81047
# Epoch 86/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4135 - acc: 0.8698 - val_loss: 0.0073 - val_acc: 0.7731
#
# Epoch 00086: val_acc did not improve from 0.81047
# Epoch 87/100
# 1013/1013 [==============================] - 116s 115ms/step - loss: 0.4182 - acc: 0.8649 - val_loss: 2.2287 - val_acc: 0.8055
#
# Epoch 00087: val_acc did not improve from 0.81047
# Epoch 88/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4202 - acc: 0.8680 - val_loss: 0.1354 - val_acc: 0.7993
#
# Epoch 00088: val_acc did not improve from 0.81047
# Epoch 89/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.4269 - acc: 0.8667 - val_loss: 0.0677 - val_acc: 0.8092
#
# Epoch 00089: val_acc did not improve from 0.81047
# Epoch 90/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.4207 - acc: 0.8659 - val_loss: 0.6287 - val_acc: 0.8042
#
# Epoch 00090: val_acc did not improve from 0.81047
# Epoch 91/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4051 - acc: 0.8728 - val_loss: 0.6562 - val_acc: 0.7855
#
# Epoch 00091: val_acc did not improve from 0.81047
# Epoch 92/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4079 - acc: 0.8723 - val_loss: 0.5744 - val_acc: 0.7880
#
# Epoch 00092: val_acc did not improve from 0.81047
# Epoch 93/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4162 - acc: 0.8715 - val_loss: 2.3539 - val_acc: 0.7868
#
# Epoch 00093: val_acc did not improve from 0.81047
# Epoch 94/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4129 - acc: 0.8695 - val_loss: 0.0976 - val_acc: 0.8117
#
# Epoch 00094: val_acc improved from 0.81047 to 0.81172, saving model to /floyd/home/m12_t1.h5
# Epoch 95/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.4078 - acc: 0.8723 - val_loss: 0.1047 - val_acc: 0.8155
#
# Epoch 00095: val_acc improved from 0.81172 to 0.81546, saving model to /floyd/home/m12_t1.h5
# Epoch 96/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.3832 - acc: 0.8798 - val_loss: 0.4962 - val_acc: 0.7968
#
# Epoch 00096: val_acc did not improve from 0.81546
# Epoch 97/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.3800 - acc: 0.8789 - val_loss: 0.3479 - val_acc: 0.8304
#
# Epoch 00097: val_acc improved from 0.81546 to 0.83042, saving model to /floyd/home/m12_t1.h5
# Epoch 98/100
# 1013/1013 [==============================] - 117s 116ms/step - loss: 0.3735 - acc: 0.8762 - val_loss: 1.3481 - val_acc: 0.7893
#
# Epoch 00098: val_acc did not improve from 0.83042
# Epoch 99/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.3894 - acc: 0.8768 - val_loss: 0.5768 - val_acc: 0.8055
#
# Epoch 00099: val_acc did not improve from 0.83042
# Epoch 100/100
# 1013/1013 [==============================] - 117s 115ms/step - loss: 0.3618 - acc: 0.8837 - val_loss: 0.7319 - val_acc: 0.7880
#
# Epoch 00100: val_acc did not improve from 0.83042
# CPU times: user 3h 41min 55s, sys: 42min 38s, total: 4h 24min 34s
# Wall time: 3h 15min 59s

# %%
# creating dictionary for model names, models, and histories from respective lists
models_dict = {i:[j,k] for i,j,k in zip(model_names,model_list,model_hists)}

# %%
# evaluating models on validation set
for key, value in models_dict.items():
    model = models.load_model(f'{model_path}{key}.h5')
    (val_loss, val_accuracy) = model.evaluate(val_generator,verbose=1)
    print(f'{key} Val Accuracy: {round((val_accuracy*100),2)}%')
    print(f'{key} Val Loss: {round(val_loss,4)}')
    print('---')
# Out:
# 102/102 [==============================] - 4s 40ms/step
# m12_t1 Val Accuracy: 82.1%
# m12_t1 Val Loss: 0.0
# ---

# %%
# saving training histories
for key, value in models_dict.items():
    with open(f'{model_path}{key}_history', 'wb') as file_pi:
        pickle.dump(value[1].history, file_pi)
    print(f'{key}_history saved in {model_path}')
# Out:
# m12_t1_history saved in /floyd/home/
