# %% [markdown]
# # Model 13: Further Capacity Increase

# %% [markdown]
# This notebook contains the construction and training of the model iterations and various experiments. The notebook is split up into four sections: training mode selection (where the model will run), set-up, model constrution, and training.
#
# Evaluation will take place in the *model_optimization_and_evaluation.ipynb* notebook found in the *notebooks* folder.

# %%
# importing necessary packages and libraries
import numpy as np
import pandas as pd
from keras import layers
from keras import models
from keras import optimizers
from keras import applications 
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import pickle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Step 1: Training Mode Selection

# %% [markdown]
# In the cell below, specify the training mode for the model. This will determine the location from which the source data is drawn, and to which the trained models (and training histories) are saved.

# %% [markdown]
# - **training_mode = 'floydhub'** (runs on Floydhub)
# - **training_mode = 'local'** (runs on local disk and processor)

# %%
# select training mode
training_mode = 'floydhub'

# %% [markdown]
# ## Step 2: Set-up

# %%
# directory base paths
data_path_local = '../../data/0002_array_data/train_data/'
model_path_local = '../../notebooks/model_construction/saved_models/'
data_path_floydhub = '/floyd/input/capstone_mushrooms/'
model_path_floydhub = '/floyd/home/'

# setting directory paths based on training mode selection
if training_mode == 'floydhub':
    data_path = data_path_floydhub
    model_path = model_path_floydhub
elif training_mode == 'local':
    data_path = data_path_local
    model_path = model_path_local
else:
    raise Exception('Please choose valid training mode: "floydhub" or "local".')

# %%
# loading the training and validation data subsets
X_train = np.load(f'{data_path}X_train_data.npy')
y_train = np.load(f'{data_path}y_train_data.npy')
X_val = np.load(f'{data_path}X_val_data.npy')
y_val = np.load(f'{data_path}y_val_data.npy')

# %%
# setting training parameters
batch_size = 8
n_classes = 20
n_epochs = 100
img_shape = X_train.shape[1:]
model_names = []
model_list = []
model_hists = []

# %% [markdown]
# ## Step 3: Model Construction

# %% [markdown]
# ### Trial 1

# %%
# defining the model architecture
m13_t1 = models.Sequential()

# convolution/max pool stacks
m13_t1.add(layers.Conv2D(64,(3,3), input_shape=img_shape, padding='same'))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.MaxPooling2D((2,2)))

m13_t1.add(layers.Conv2D(128,(3,3), padding='same'))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.MaxPooling2D((2,2)))

m13_t1.add(layers.Conv2D(256,(3,3), padding='same'))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.MaxPooling2D((2,2)))

m13_t1.add(layers.Conv2D(512,(3,3), padding='same'))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.MaxPooling2D((2,2)))

m13_t1.add(layers.Conv2D(512,(3,3), padding='same'))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.MaxPooling2D((2,2)))

# fully connected layers
m13_t1.add(layers.Flatten())
m13_t1.add(layers.Dense(1024))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.Dropout(0.25))
m13_t1.add(layers.Dense(2048))
m13_t1.add(layers.LeakyReLU(alpha=0.1))
m13_t1.add(layers.Dropout(0.25))
m13_t1.add(layers.Dense(n_classes, activation='softmax'))

# reviewing the model architecture and adding model and name to list
m13_t1.summary()
model_names.append('m13_t1')
model_list.append(m13_t1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200, 200, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 100, 128)     73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100, 100, 128)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 50, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 256)       295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 50, 50, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 25, 25, 512)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 512)       2359808
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              18875392
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                40980
# =================================================================
# Total params: 24,926,356
# Trainable params: 24,926,356
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Step 4: Training

# %%
# setting up standardization and augmentation parameters
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=40,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   shear_range=0.3,
                                   zoom_range=0.3,
                                   fill_mode='nearest',
                                   horizontal_flip=True,
                                   vertical_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# %%time
# data standardization and augmentation
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)
# Out:
# CPU times: user 336 ms, sys: 970 ms, total: 1.31 s
# Wall time: 1.3 s

# %%
# setting up optimizer
opt = optimizers.Adamax(learning_rate=9e-4)

# compiling loss functions
m13_t1.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['acc'])

# %%
# %%time
# setting up model saving checkpoints
m13_t1_cp = ModelCheckpoint(filepath=f'{model_path}m13_t1.h5',
                              monitor='val_acc',
                              verbose=1,
                              save_best_only=True)

# fitting model
m13_t1_history = m13_t1.fit(train_generator,
                                steps_per_epoch=len(X_train)//batch_size,
                                epochs=n_epochs,
                                callbacks=[m13_t1_cp],
                                validation_data=val_generator,
                                validation_steps=len(X_val)//batch_size)

# adding training history to list
model_hists.append(m13_t1_history)
# Out:
# Epoch 1/100
# 1013/1013 [==============================] - 167s 165ms/step - loss: 2.7009 - acc: 0.1338 - val_loss: 3.0273 - val_acc: 0.1807
#
# Epoch 00001: val_acc improved from -inf to 0.18069, saving model to /floyd/home/m13_t1.h5
# Epoch 2/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 2.4074 - acc: 0.2102 - val_loss: 1.6333 - val_acc: 0.3329
#
# Epoch 00002: val_acc improved from 0.18069 to 0.33292, saving model to /floyd/home/m13_t1.h5
# Epoch 3/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 2.2199 - acc: 0.2780 - val_loss: 1.9310 - val_acc: 0.4027
#
# Epoch 00003: val_acc improved from 0.33292 to 0.40274, saving model to /floyd/home/m13_t1.h5
# Epoch 4/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 2.0873 - acc: 0.3253 - val_loss: 1.9455 - val_acc: 0.4027
#
# Epoch 00004: val_acc did not improve from 0.40274
# Epoch 5/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.9902 - acc: 0.3584 - val_loss: 2.5805 - val_acc: 0.4414
#
# Epoch 00005: val_acc improved from 0.40274 to 0.44140, saving model to /floyd/home/m13_t1.h5
# Epoch 6/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.9025 - acc: 0.3848 - val_loss: 1.9257 - val_acc: 0.4613
#
# Epoch 00006: val_acc improved from 0.44140 to 0.46135, saving model to /floyd/home/m13_t1.h5
# Epoch 7/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.8343 - acc: 0.4144 - val_loss: 1.8644 - val_acc: 0.5237
#
# Epoch 00007: val_acc improved from 0.46135 to 0.52369, saving model to /floyd/home/m13_t1.h5
# Epoch 8/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.7670 - acc: 0.4327 - val_loss: 1.2413 - val_acc: 0.4963
#
# Epoch 00008: val_acc did not improve from 0.52369
# Epoch 9/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.7070 - acc: 0.4564 - val_loss: 1.7111 - val_acc: 0.5449
#
# Epoch 00009: val_acc improved from 0.52369 to 0.54489, saving model to /floyd/home/m13_t1.h5
# Epoch 10/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.6514 - acc: 0.4719 - val_loss: 1.4424 - val_acc: 0.4738
#
# Epoch 00010: val_acc did not improve from 0.54489
# Epoch 11/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.5978 - acc: 0.4946 - val_loss: 1.9155 - val_acc: 0.5362
#
# Epoch 00011: val_acc did not improve from 0.54489
# Epoch 12/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.5398 - acc: 0.5095 - val_loss: 0.9886 - val_acc: 0.5474
#
# Epoch 00012: val_acc improved from 0.54489 to 0.54738, saving model to /floyd/home/m13_t1.h5
# Epoch 13/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.5148 - acc: 0.5128 - val_loss: 1.1850 - val_acc: 0.5748
#
# Epoch 00013: val_acc improved from 0.54738 to 0.57481, saving model to /floyd/home/m13_t1.h5
# Epoch 14/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.4789 - acc: 0.5291 - val_loss: 1.5204 - val_acc: 0.5636
#
# Epoch 00014: val_acc did not improve from 0.57481
# Epoch 15/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.4107 - acc: 0.5480 - val_loss: 2.7706 - val_acc: 0.6110
#
# Epoch 00015: val_acc improved from 0.57481 to 0.61097, saving model to /floyd/home/m13_t1.h5
# Epoch 16/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.3778 - acc: 0.5627 - val_loss: 0.6055 - val_acc: 0.6060
#
# Epoch 00016: val_acc did not improve from 0.61097
# Epoch 17/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.3462 - acc: 0.5710 - val_loss: 2.4971 - val_acc: 0.5673
#
# Epoch 00017: val_acc did not improve from 0.61097
# Epoch 18/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.3051 - acc: 0.5832 - val_loss: 0.8181 - val_acc: 0.5736
#
# Epoch 00018: val_acc did not improve from 0.61097
# Epoch 19/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.2732 - acc: 0.5830 - val_loss: 0.8863 - val_acc: 0.6185
#
# Epoch 00019: val_acc improved from 0.61097 to 0.61845, saving model to /floyd/home/m13_t1.h5
# Epoch 20/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.2372 - acc: 0.6073 - val_loss: 0.7267 - val_acc: 0.6272
#
# Epoch 00020: val_acc improved from 0.61845 to 0.62718, saving model to /floyd/home/m13_t1.h5
# Epoch 21/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.1873 - acc: 0.6175 - val_loss: 1.2271 - val_acc: 0.6733
#
# Epoch 00021: val_acc improved from 0.62718 to 0.67332, saving model to /floyd/home/m13_t1.h5
# Epoch 22/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.1585 - acc: 0.6310 - val_loss: 1.3426 - val_acc: 0.6060
#
# Epoch 00022: val_acc did not improve from 0.67332
# Epoch 23/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.1321 - acc: 0.6420 - val_loss: 2.8204 - val_acc: 0.6534
#
# Epoch 00023: val_acc did not improve from 0.67332
# Epoch 24/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.0829 - acc: 0.6485 - val_loss: 0.9907 - val_acc: 0.6758
#
# Epoch 00024: val_acc improved from 0.67332 to 0.67581, saving model to /floyd/home/m13_t1.h5
# Epoch 25/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.0719 - acc: 0.6535 - val_loss: 1.7969 - val_acc: 0.6446
#
# Epoch 00025: val_acc did not improve from 0.67581
# Epoch 26/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.0623 - acc: 0.6595 - val_loss: 2.0999 - val_acc: 0.6845
#
# Epoch 00026: val_acc improved from 0.67581 to 0.68454, saving model to /floyd/home/m13_t1.h5
# Epoch 27/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 1.0314 - acc: 0.6719 - val_loss: 0.5932 - val_acc: 0.7232
#
# Epoch 00027: val_acc improved from 0.68454 to 0.72319, saving model to /floyd/home/m13_t1.h5
# Epoch 28/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9984 - acc: 0.6789 - val_loss: 0.4392 - val_acc: 0.7232
#
# Epoch 00028: val_acc did not improve from 0.72319
# Epoch 29/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9823 - acc: 0.6862 - val_loss: 0.3085 - val_acc: 0.6945
#
# Epoch 00029: val_acc did not improve from 0.72319
# Epoch 30/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9794 - acc: 0.6849 - val_loss: 1.0685 - val_acc: 0.6384
#
# Epoch 00030: val_acc did not improve from 0.72319
# Epoch 31/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9389 - acc: 0.6996 - val_loss: 1.8426 - val_acc: 0.7282
#
# Epoch 00031: val_acc improved from 0.72319 to 0.72818, saving model to /floyd/home/m13_t1.h5
# Epoch 32/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9254 - acc: 0.7066 - val_loss: 0.9805 - val_acc: 0.6808
#
# Epoch 00032: val_acc did not improve from 0.72818
# Epoch 33/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.9154 - acc: 0.7048 - val_loss: 0.1504 - val_acc: 0.7095
#
# Epoch 00033: val_acc did not improve from 0.72818
# Epoch 34/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8854 - acc: 0.7164 - val_loss: 1.0974 - val_acc: 0.7170
#
# Epoch 00034: val_acc did not improve from 0.72818
# Epoch 35/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8720 - acc: 0.7168 - val_loss: 0.1589 - val_acc: 0.7481
#
# Epoch 00035: val_acc improved from 0.72818 to 0.74813, saving model to /floyd/home/m13_t1.h5
# Epoch 36/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8760 - acc: 0.7189 - val_loss: 1.7417 - val_acc: 0.7531
#
# Epoch 00036: val_acc improved from 0.74813 to 0.75312, saving model to /floyd/home/m13_t1.h5
# Epoch 37/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8091 - acc: 0.7372 - val_loss: 0.7699 - val_acc: 0.7681
#
# Epoch 00037: val_acc improved from 0.75312 to 0.76808, saving model to /floyd/home/m13_t1.h5
# Epoch 38/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8229 - acc: 0.7341 - val_loss: 0.4647 - val_acc: 0.7594
#
# Epoch 00038: val_acc did not improve from 0.76808
# Epoch 39/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8163 - acc: 0.7383 - val_loss: 1.5883 - val_acc: 0.7282
#
# Epoch 00039: val_acc did not improve from 0.76808
# Epoch 40/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.8110 - acc: 0.7367 - val_loss: 1.5991 - val_acc: 0.7307
#
# Epoch 00040: val_acc did not improve from 0.76808
# Epoch 41/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7737 - acc: 0.7554 - val_loss: 0.2620 - val_acc: 0.7456
#
# Epoch 00041: val_acc did not improve from 0.76808
# Epoch 42/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7726 - acc: 0.7470 - val_loss: 1.3054 - val_acc: 0.7045
#
# Epoch 00042: val_acc did not improve from 0.76808
# Epoch 43/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7524 - acc: 0.7520 - val_loss: 1.9749 - val_acc: 0.6970
#
# Epoch 00043: val_acc did not improve from 0.76808
# Epoch 44/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7309 - acc: 0.7617 - val_loss: 0.8269 - val_acc: 0.7057
#
# Epoch 00044: val_acc did not improve from 0.76808
# Epoch 45/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7356 - acc: 0.7666 - val_loss: 0.2018 - val_acc: 0.7307
#
# Epoch 00045: val_acc did not improve from 0.76808
# Epoch 46/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7114 - acc: 0.7721 - val_loss: 0.9642 - val_acc: 0.7307
#
# Epoch 00046: val_acc did not improve from 0.76808
# Epoch 47/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.7051 - acc: 0.7700 - val_loss: 0.7053 - val_acc: 0.7132
#
# Epoch 00047: val_acc did not improve from 0.76808
# Epoch 48/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6995 - acc: 0.7753 - val_loss: 0.8499 - val_acc: 0.7569
#
# Epoch 00048: val_acc did not improve from 0.76808
# Epoch 49/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6627 - acc: 0.7856 - val_loss: 0.4212 - val_acc: 0.8017
#
# Epoch 00049: val_acc improved from 0.76808 to 0.80175, saving model to /floyd/home/m13_t1.h5
# Epoch 50/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6649 - acc: 0.7872 - val_loss: 0.2726 - val_acc: 0.7506
#
# Epoch 00050: val_acc did not improve from 0.80175
# Epoch 51/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6458 - acc: 0.7925 - val_loss: 0.6315 - val_acc: 0.7594
#
# Epoch 00051: val_acc did not improve from 0.80175
# Epoch 52/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6593 - acc: 0.7894 - val_loss: 0.4303 - val_acc: 0.7394
#
# Epoch 00052: val_acc did not improve from 0.80175
# Epoch 53/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6429 - acc: 0.7927 - val_loss: 0.9091 - val_acc: 0.7918
#
# Epoch 00053: val_acc did not improve from 0.80175
# Epoch 54/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6389 - acc: 0.7932 - val_loss: 0.0653 - val_acc: 0.7668
#
# Epoch 00054: val_acc did not improve from 0.80175
# Epoch 55/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6229 - acc: 0.8022 - val_loss: 0.8947 - val_acc: 0.7905
#
# Epoch 00055: val_acc did not improve from 0.80175
# Epoch 56/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6169 - acc: 0.8021 - val_loss: 0.8069 - val_acc: 0.7207
#
# Epoch 00056: val_acc did not improve from 0.80175
# Epoch 57/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.6132 - acc: 0.8032 - val_loss: 0.4940 - val_acc: 0.7681
#
# Epoch 00057: val_acc did not improve from 0.80175
# Epoch 58/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5893 - acc: 0.8094 - val_loss: 1.6737 - val_acc: 0.7369
#
# Epoch 00058: val_acc did not improve from 0.80175
# Epoch 59/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5893 - acc: 0.8109 - val_loss: 0.2016 - val_acc: 0.7718
#
# Epoch 00059: val_acc did not improve from 0.80175
# Epoch 60/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5868 - acc: 0.8128 - val_loss: 0.0829 - val_acc: 0.7244
#
# Epoch 00060: val_acc did not improve from 0.80175
# Epoch 61/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5707 - acc: 0.8159 - val_loss: 2.4054 - val_acc: 0.7693
#
# Epoch 00061: val_acc did not improve from 0.80175
# Epoch 62/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5587 - acc: 0.8216 - val_loss: 1.8724 - val_acc: 0.7469
#
# Epoch 00062: val_acc did not improve from 0.80175
# Epoch 63/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5368 - acc: 0.8258 - val_loss: 0.4209 - val_acc: 0.7855
#
# Epoch 00063: val_acc did not improve from 0.80175
# Epoch 64/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5559 - acc: 0.8225 - val_loss: 0.1200 - val_acc: 0.7893
#
# Epoch 00064: val_acc did not improve from 0.80175
# Epoch 65/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5452 - acc: 0.8285 - val_loss: 0.1331 - val_acc: 0.7843
#
# Epoch 00065: val_acc did not improve from 0.80175
# Epoch 66/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5214 - acc: 0.8306 - val_loss: 1.2070 - val_acc: 0.7544
#
# Epoch 00066: val_acc did not improve from 0.80175
# Epoch 67/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5456 - acc: 0.8264 - val_loss: 0.6695 - val_acc: 0.7880
#
# Epoch 00067: val_acc did not improve from 0.80175
# Epoch 68/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4968 - acc: 0.8400 - val_loss: 1.2000 - val_acc: 0.7756
#
# Epoch 00068: val_acc did not improve from 0.80175
# Epoch 69/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5323 - acc: 0.8331 - val_loss: 1.2071 - val_acc: 0.7905
#
# Epoch 00069: val_acc did not improve from 0.80175
# Epoch 70/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5199 - acc: 0.8338 - val_loss: 1.1773 - val_acc: 0.7531
#
# Epoch 00070: val_acc did not improve from 0.80175
# Epoch 71/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.5027 - acc: 0.8375 - val_loss: 0.4482 - val_acc: 0.7918
#
# Epoch 00071: val_acc did not improve from 0.80175
# Epoch 72/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4871 - acc: 0.8437 - val_loss: 0.7854 - val_acc: 0.7594
#
# Epoch 00072: val_acc did not improve from 0.80175
# Epoch 73/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4864 - acc: 0.8409 - val_loss: 0.3086 - val_acc: 0.7918
#
# Epoch 00073: val_acc did not improve from 0.80175
# Epoch 74/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4988 - acc: 0.8440 - val_loss: 0.5917 - val_acc: 0.7556
#
# Epoch 00074: val_acc did not improve from 0.80175
# Epoch 75/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4778 - acc: 0.8458 - val_loss: 0.4996 - val_acc: 0.7344
#
# Epoch 00075: val_acc did not improve from 0.80175
# Epoch 76/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4709 - acc: 0.8499 - val_loss: 2.5093 - val_acc: 0.7693
#
# Epoch 00076: val_acc did not improve from 0.80175
# Epoch 77/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4823 - acc: 0.8488 - val_loss: 0.9038 - val_acc: 0.7880
#
# Epoch 00077: val_acc did not improve from 0.80175
# Epoch 78/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4730 - acc: 0.8468 - val_loss: 0.3865 - val_acc: 0.8404
#
# Epoch 00078: val_acc improved from 0.80175 to 0.84040, saving model to /floyd/home/m13_t1.h5
# Epoch 79/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4591 - acc: 0.8535 - val_loss: 0.1603 - val_acc: 0.7444
#
# Epoch 00079: val_acc did not improve from 0.84040
# Epoch 80/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4492 - acc: 0.8560 - val_loss: 0.3670 - val_acc: 0.7868
#
# Epoch 00080: val_acc did not improve from 0.84040
# Epoch 81/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4570 - acc: 0.8538 - val_loss: 0.0712 - val_acc: 0.7781
#
# Epoch 00081: val_acc did not improve from 0.84040
# Epoch 82/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4404 - acc: 0.8606 - val_loss: 0.0052 - val_acc: 0.7855
#
# Epoch 00082: val_acc did not improve from 0.84040
# Epoch 83/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4413 - acc: 0.8628 - val_loss: 0.5251 - val_acc: 0.7955
#
# Epoch 00083: val_acc did not improve from 0.84040
# Epoch 84/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4511 - acc: 0.8551 - val_loss: 0.2454 - val_acc: 0.8130
#
# Epoch 00084: val_acc did not improve from 0.84040
# Epoch 85/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4284 - acc: 0.8586 - val_loss: 2.7583 - val_acc: 0.7880
#
# Epoch 00085: val_acc did not improve from 0.84040
# Epoch 86/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4234 - acc: 0.8645 - val_loss: 0.0949 - val_acc: 0.8042
#
# Epoch 00086: val_acc did not improve from 0.84040
# Epoch 87/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4327 - acc: 0.8621 - val_loss: 0.3542 - val_acc: 0.7943
#
# Epoch 00087: val_acc did not improve from 0.84040
# Epoch 88/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4225 - acc: 0.8670 - val_loss: 0.9467 - val_acc: 0.7668
#
# Epoch 00088: val_acc did not improve from 0.84040
# Epoch 89/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4105 - acc: 0.8685 - val_loss: 0.0485 - val_acc: 0.8042
#
# Epoch 00089: val_acc did not improve from 0.84040
# Epoch 90/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4231 - acc: 0.8666 - val_loss: 1.0080 - val_acc: 0.7332
#
# Epoch 00090: val_acc did not improve from 0.84040
# Epoch 91/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4084 - acc: 0.8723 - val_loss: 0.1658 - val_acc: 0.8005
#
# Epoch 00091: val_acc did not improve from 0.84040
# Epoch 92/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3942 - acc: 0.8754 - val_loss: 0.5567 - val_acc: 0.7843
#
# Epoch 00092: val_acc did not improve from 0.84040
# Epoch 93/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4120 - acc: 0.8678 - val_loss: 0.3581 - val_acc: 0.7768
#
# Epoch 00093: val_acc did not improve from 0.84040
# Epoch 94/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3956 - acc: 0.8742 - val_loss: 1.9552 - val_acc: 0.7681
#
# Epoch 00094: val_acc did not improve from 0.84040
# Epoch 95/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4060 - acc: 0.8759 - val_loss: 0.3180 - val_acc: 0.7905
#
# Epoch 00095: val_acc did not improve from 0.84040
# Epoch 96/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3986 - acc: 0.8744 - val_loss: 0.5370 - val_acc: 0.8092
#
# Epoch 00096: val_acc did not improve from 0.84040
# Epoch 97/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3940 - acc: 0.8723 - val_loss: 0.1062 - val_acc: 0.7968
#
# Epoch 00097: val_acc did not improve from 0.84040
# Epoch 98/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.4039 - acc: 0.8728 - val_loss: 0.2251 - val_acc: 0.7993
#
# Epoch 00098: val_acc did not improve from 0.84040
# Epoch 99/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3705 - acc: 0.8835 - val_loss: 0.2050 - val_acc: 0.7855
#
# Epoch 00099: val_acc did not improve from 0.84040
# Epoch 100/100
# 1013/1013 [==============================] - 119s 118ms/step - loss: 0.3763 - acc: 0.8809 - val_loss: 2.3325 - val_acc: 0.7830
#
# Epoch 00100: val_acc did not improve from 0.84040
# CPU times: user 3h 43min 55s, sys: 43min 34s, total: 4h 27min 29s
# Wall time: 3h 20min 34s

# %%
# creating dictionary for model names, models, and histories from respective lists
models_dict = {i:[j,k] for i,j,k in zip(model_names,model_list,model_hists)}

# %%
# evaluating models on validation set
for key, value in models_dict.items():
    model = models.load_model(f'{model_path}{key}.h5')
    (val_loss, val_accuracy) = model.evaluate(val_generator,verbose=1)
    print(f'{key} Val Accuracy: {round((val_accuracy*100),2)}%')
    print(f'{key} Val Loss: {round(val_loss,4)}')
    print('---')
# Out:
# 102/102 [==============================] - 4s 40ms/step
# m13_t1 Val Accuracy: 82.96%
# m13_t1 Val Loss: 0.0
# ---

# %%
# saving training histories
for key, value in models_dict.items():
    with open(f'{model_path}{key}_history', 'wb') as file_pi:
        pickle.dump(value[1].history, file_pi)
    print(f'{key}_history saved in {model_path}')
# Out:
# m13_t1_history saved in /floyd/home/
